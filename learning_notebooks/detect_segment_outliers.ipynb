# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import folium
from folium import FeatureGroup, LayerControl, Map, Marker
import pandas as pd
import random
from scipy import stats
# %matplotlib inline

# %% [markdown]
# ## Consts

# %%
PROVIDER_AND_ID = "provider_and_id"
YEAR = "accident_year"
LAT = "latitude"
LONG = "longitude"
X = "x"
Y = "y"
SEVERITY = "injury_severity_hebrew"
ROAD_SEGMENT_NAME = 'road_segment_name'
ROAD_SEGMENT = 'road_segment_id'
ROAD_SEGMENT_LENGTH = 'road_segment_length_km'
SEVERITY_DEAD = 'הרוג'
SEVERITY_HARD = 'פצוע קשה'
RELEVANT_KEYS_ANALYSIS = [PROVIDER_AND_ID, YEAR, ROAD_SEGMENT_NAME, ROAD_SEGMENT, ROAD_SEGMENT_LENGTH, LAT, LONG, X, Y, SEVERITY]

DEFAULT_ZOOM = 9
FROM_YEAR = 2014
KM_FROM_MEDIAN = 'km_from_median'
DEFAULT_COORD = (32.079184, 34.824768)

# %% [markdown]
# ## Load data

# %%
csv_path = r"views2020/involved_markers_hebrew.csv"
data = pd.read_csv(csv_path, na_values='')

# %%
# get only relevant data
filtered = data[RELEVANT_KEYS_ANALYSIS].drop_duplicates(subset=[PROVIDER_AND_ID, LAT, LONG])
# from this year the data was corrected
filtered = filtered[filtered[YEAR] >= FROM_YEAR]
filtered
# Out:
#          provider_and_id  accident_year  \
# 726          12015000826           2015
# 727          12015002360           2015
# 728          12015003578           2015
# 729          12015006896           2015
# 733          12015006964           2015
# ...                  ...            ...
# 1881289      32020025415           2020
# 1881292      32020032761           2020
# 1881293      32020033896           2020
# 1881299      32020049734           2020
# 1881301      32020053498           2020
#
#                                   road_segment_name  road_segment_id  \
# 726                                             NaN              NaN
# 727                       צומת מחסיה - צומת נס הרים       38660010.0
# 728                                             NaN              NaN
# 729      כניסה למנהרה - כניסה לדרך האלוף עוזי נרקיס          10090.0
# 733                                             NaN              NaN
# ...                                             ...              ...
# 1881289                       מחלף גהה - מחלף מורשה          40140.0
# 1881292                                         NaN              NaN
# 1881293                                         NaN              NaN
# 1881299                                         NaN              NaN
# 1881301                                         NaN              NaN
#
#          road_segment_length_km   latitude  longitude         x         y  \
# 726                         NaN  32.043049  34.770967  178508.0  661167.0
# 727                         9.0  31.745920  35.014625  201464.0  628153.0
# 728                         NaN  32.525085  35.161378  215404.0  714540.0
# 729                         9.0  31.801289  35.184305  217543.0  634277.0
# 733                         NaN  32.320981  34.863568  187352.0  691956.0
# ...                         ...        ...        ...       ...       ...
# 1881289                     3.7  32.092494  34.845892  185603.0  666624.0
# 1881292                     NaN  32.081712  34.796332  180920.0  665445.0
# 1881293                     NaN  32.954099  35.163235  215597.0  762118.0
# 1881299                     NaN  32.059339  34.766696  178112.0  662975.0
# 1881301                     NaN  32.039059  34.777549  179128.0  660722.0
#
#         injury_severity_hebrew
# 726                    פצוע קל
# 727                        NaN
# 728                    פצוע קל
# 729                    פצוע קל
# 733                        NaN
# ...                        ...
# 1881289                פצוע קל
# 1881292                פצוע קל
# 1881293                פצוע קל
# 1881299                פצוע קל
# 1881301                פצוע קל
#
# [373239 rows x 10 columns]

# %% [markdown]
# ## Plot funcs

# %%
def create_map(coord):
    
    folium_map = folium.Map(location=coord, zoom_start=DEFAULT_ZOOM)
    
    return folium_map

# %%
def plot_coord(folium_map, coord, count, color, icon):
   
    tooltip = 'Click to see accident counts'
    folium.Marker(coord, icon=folium.Icon(color=color, icon=icon), 
                  popup=f'<i>{count}</i>', tooltip=tooltip).add_to(folium_map)

# %%
def plot_all_coords(coords, folium_map, color='green', icon='ok-sign'):
    """
    Plot all coords according to location and count
    """

    coord_to_count = coords.groupby([LAT, LONG]).size()
    
    for coord, count in coord_to_count.items():
        plot_coord(folium_map, coord, count, color=color, icon=icon)
    
    return coord_to_count

# %%
def get_median_coord(coords, decimals=4):
    
    return tuple(np.around(np.median(coords[[LAT, LONG]], axis=0), decimals))

# %%
def plot_median_coord(median_coord, coord_to_count, folium_map, color, icon):
    
    count = coord_to_count[median_coord] if median_coord in coord_to_count else 1
    plot_coord(folium_map, median_coord, count, color=color, icon=icon)

# %%
def plot_all_segment_coords(segment_rows, outlier_rows, segment_map_layer, decimals=4):
    """
    Plot all coords in segment, rounded to decimals, according to their location and count
    Median is blue, outliers are red, all other coords are green
    
    Keyword arguments:
    segment_rows -- segment rows without outliers
    outlier_rows -- outlier segment rows
    segment_map_layer -- points are added to this layer
    decimals -- round to decimals, very close points are merged 
                to the same point with a larger count
    """
    
    segment_coords = segment_rows[[LAT, LONG]].dropna().round(decimals=decimals)
    outlier_coords = outlier_rows[[LAT, LONG]].dropna().round(decimals=decimals)
    
    coord_to_count = plot_all_coords(segment_coords, segment_map_layer, color='green', icon='ok-sign')
    
    median_coord = get_median_coord(segment_coords, decimals=decimals)
    plot_median_coord(median_coord, coord_to_count, segment_map_layer, color='blue', icon='screenshot')
    
    plot_all_coords(outlier_coords, segment_map_layer, color='red', icon='exclamation-sign')

# %%
def get_segment_rows(data, road_segment_id, max_coords=None):
    
    segment_rows = data[data[ROAD_SEGMENT]==road_segment_id]
    
    return segment_rows[:max_coords]

# %%
def plot_outliers(data, outliers, max_coords=500):
    
    outlier_map = create_map(DEFAULT_COORD)
    
    for road_segment_id, outlier_rows in outliers.groupby(ROAD_SEGMENT):
        
        first_outlier = outlier_rows.iloc[0]
        segment_name = first_outlier[ROAD_SEGMENT_NAME]
        segment_length = round(first_outlier[ROAD_SEGMENT_LENGTH], 1)
        road_segment_id = int(road_segment_id)
        
        segment_rows = get_segment_rows(data, road_segment_id, max_coords)
        segment_rows = segment_rows[~segment_rows[PROVIDER_AND_ID].isin(outlier_rows[PROVIDER_AND_ID])]
        
        segment_map_layer = FeatureGroup(name=f'{road_segment_id} {segment_length} km {segment_name}', show=False)
        plot_all_segment_coords(segment_rows, outlier_rows, segment_map_layer)
        
        segment_map_layer.add_to(outlier_map)
        
    LayerControl().add_to(outlier_map)
    
    return outlier_map

# %% [markdown]
# ## Find outliers by km from median

# %%
def spherical_distance(lat1, long1, lat2, long2):
    """
    Calculate the spherical distance in km between two coordinates in WGS-84 using Vincenty's formulae
    
    credit: https://www.johndcook.com/blog/2018/11/24/spheroid-distance/
    """

    lat1, long1, lat2, long2 = np.deg2rad(lat1), np.deg2rad(long1), np.deg2rad(lat2), np.deg2rad(long2)
    
    phi1 = 0.5*np.pi - lat1
    phi2 = 0.5*np.pi - lat2
    r = 0.5*(6378137 + 6356752) # mean radius in meters
    t = np.sin(phi1)*np.sin(phi2)*np.cos(long1-long2) + np.cos(phi1)*np.cos(phi2)
    
    # -1<=t<=1 for the arcos func
    t = np.minimum(t, 1)
    t = np.maximum(t, -1)
    
    return round(r * np.arccos(t) / 1000, 2)

# %%
def is_far_from_median(data, row, outliers, segment_length, padding):
    """
    Check if the distance of row from the median_coord is > segment_length + padding*segment_length
    The median is computed according to all coords, after removing the outliers and the current coord
    """
    
    curr_coord = [row[LAT], row[LONG]]

    data_without_outlier = data[~data[PROVIDER_AND_ID].isin(outliers) & data[PROVIDER_AND_ID] != row[PROVIDER_AND_ID]]

    median_coord = np.median(data_without_outlier[[LAT, LONG]], axis=0)

    dist = spherical_distance(*curr_coord, *median_coord)

    return dist > segment_length + padding*segment_length

# %%
def get_segment_outliers_far_from_median(data, segment_length, padding):
    
    outliers = []
    
    for i, row in data.iterrows():
        if is_far_from_median(data, row, outliers, segment_length, padding):
            outliers.append(row[PROVIDER_AND_ID])
            
    return outliers

# %%
def add_km_from_median_col(other_data, outliers_data):
    
    median_coord = np.median(other_data[[LAT, LONG]], axis=0)

    outliers_data[KM_FROM_MEDIAN] = outliers_data.apply(lambda row: spherical_distance(row[LAT], row[LONG], *median_coord), axis=1)
    outliers_data = outliers_data.sort_values(by=KM_FROM_MEDIAN)
    
    return outliers_data

# %%
def calc_outliers_for_segment_km(data, min_sample_size, padding=0.25):
     
    data = data.dropna(subset=[LAT, LONG])
    
    if len(data) <= min_sample_size:
        return []
    
    segment_length = data.iloc[0][ROAD_SEGMENT_LENGTH]
    
    outliers = get_segment_outliers_far_from_median(data, segment_length, padding)

    outliers_data = data[data[PROVIDER_AND_ID].isin(outliers)].copy(deep=True)
    other_data = data[~data[PROVIDER_AND_ID].isin(outliers)].copy(deep=True)
    
    if len(outliers) > 0:
        outliers_data = add_km_from_median_col(other_data, outliers_data)
        
    return outliers_data

# %%
def get_outliers_by_km(data, min_sample_size=2):
    
    res = []
    for seg, rows in data.groupby(ROAD_SEGMENT):
        outliers = calc_outliers_for_segment_km(rows, min_sample_size)
        if len(outliers) > 0:
            res.append(outliers)
            
    return pd.concat(res)

# %% [markdown]
# ### Old method:

# %%
def calc_zscores(data, zscore_thresh, min_sample_size):

    coords = data[[X, Y]].dropna()
    
    # check if sample size is big enough for the statistic calculation
    if len(coords.drop_duplicates()) <= min_sample_size:
        return []
    
    # calculate zscores for each column
    zscores = stats.zscore(coords, axis = 0)
    zscores = np.nan_to_num(zscores)
    zscores = np.abs(zscores)
    # get indices to outliers
    outliers = np.argwhere(zscores > zscore_thresh)
    outlier_rows = np.unique(outliers[:, 0])
    outlier_rows = data.iloc[outlier_rows]
    
    return outlier_rows

def calc_outliers_for_segment_zscores(data, zscore_thresh, min_sample_size, check_by_km):
    
    outlier_rows = calc_zscores(data, zscore_thresh, min_sample_size)
    
    if len(outlier_rows) > 0:
        
        if check_by_km:
            median_coord = np.median(data[[LAT, LONG]].dropna(), axis=0)
            segment_length = outlier_rows.iloc[0][ROAD_SEGMENT_LENGTH]

            outlier_rows = outlier_rows[spherical_distance(outlier_rows[LAT], outlier_rows[LONG], *median_coord) 
                                        > segment_length]
        
        return outlier_rows
    
    return []

def get_outliers_by_z_scores(data, zscore_thresh, min_sample_size=0, check_by_km=True):
    res = []
    for seg, rows in data.groupby(ROAD_SEGMENT):
        outliers = calc_outliers_for_segment_zscores(rows, zscore_thresh, min_sample_size, check_by_km)
        if len(outliers) > 0:
            res.append(outliers)
    return pd.concat(res)

# %% [markdown]
# ## Pick threshold and minimum sample size

# %%
ZSCORE_THRESH = 5
MIN_SAMPLE_SIZE = 10

# %% [markdown]
# ## Test

# %%
segmend_id = 10010
segment_rows = filtered[filtered[ROAD_SEGMENT]==segmend_id]
outliers_test = calc_outliers_for_segment_km(segment_rows, MIN_SAMPLE_SIZE)

outliers_test
# Out:
#          provider_and_id  accident_year              road_segment_name  \
# 262132       32014096076           2014  מחלף קיבוץ גלויות - מחלף גנות
# 79852        32016097605           2016  מחלף קיבוץ גלויות - מחלף גנות
# 630376       32014086342           2014  מחלף קיבוץ גלויות - מחלף גנות
# 1290954      32015074726           2015  מחלף קיבוץ גלויות - מחלף גנות
# 193073       32015032765           2015  מחלף קיבוץ גלויות - מחלף גנות
# 1096313      32016024246           2016  מחלף קיבוץ גלויות - מחלף גנות
# 293439       32014038567           2014  מחלף קיבוץ גלויות - מחלף גנות
# 298283       32014002960           2014  מחלף קיבוץ גלויות - מחלף גנות
# 33514        32015070182           2015  מחלף קיבוץ גלויות - מחלף גנות
# 171836       32015057939           2015  מחלף קיבוץ גלויות - מחלף גנות
# 779062       32019052266           2019  מחלף קיבוץ גלויות - מחלף גנות
# 1060965      32019077524           2019  מחלף קיבוץ גלויות - מחלף גנות
# 579800       32019092307           2019  מחלף קיבוץ גלויות - מחלף גנות
# 581871       32019061587           2019  מחלף קיבוץ גלויות - מחלף גנות
# 592955       12019025070           2019  מחלף קיבוץ גלויות - מחלף גנות
# 898267       32020062846           2020  מחלף קיבוץ גלויות - מחלף גנות
# 873280       32019022058           2019  מחלף קיבוץ גלויות - מחלף גנות
# 601060       32019051092           2019  מחלף קיבוץ גלויות - מחלף גנות
# 605017       32019038792           2019  מחלף קיבוץ גלויות - מחלף גנות
# 867216       32019090954           2019  מחלף קיבוץ גלויות - מחלף גנות
# 618466       12019063641           2019  מחלף קיבוץ גלויות - מחלף גנות
# 842329       32019086597           2019  מחלף קיבוץ גלויות - מחלף גנות
# 822673       32019016875           2019  מחלף קיבוץ גלויות - מחלף גנות
# 693843       12019078537           2019  מחלף קיבוץ גלויות - מחלף גנות
# 550539       32020067410           2020  מחלף קיבוץ גלויות - מחלף גנות
# 699630       32020015795           2020  מחלף קיבוץ גלויות - מחלף גנות
# 723687       32019093684           2019  מחלף קיבוץ גלויות - מחלף גנות
# 738248       32018071991           2018  מחלף קיבוץ גלויות - מחלף גנות
# 796848       32018069786           2018  מחלף קיבוץ גלויות - מחלף גנות
# 535859       32019063954           2019  מחלף קיבוץ גלויות - מחלף גנות
# 424499       32019086233           2019  מחלף קיבוץ גלויות - מחלף גנות
# 464243       32019009286           2019  מחלף קיבוץ גלויות - מחלף גנות
# 39327        32014004137           2014  מחלף קיבוץ גלויות - מחלף גנות
# 42999        12018000143           2018  מחלף קיבוץ גלויות - מחלף גנות
# 58674        32020059968           2020  מחלף קיבוץ גלויות - מחלף גנות
# 70386        32019015441           2019  מחלף קיבוץ גלויות - מחלף גנות
# 78075        32020004404           2020  מחלף קיבוץ גלויות - מחלף גנות
# 96828        32019083043           2019  מחלף קיבוץ גלויות - מחלף גנות
# 96862        32020057320           2020  מחלף קיבוץ גלויות - מחלף גנות
# 136624       32019074276           2019  מחלף קיבוץ גלויות - מחלף גנות
# 138568       32018038299           2018  מחלף קיבוץ גלויות - מחלף גנות
# 149832       12017054749           2017  מחלף קיבוץ גלויות - מחלף גנות
# 153678       32019053073           2019  מחלף קיבוץ גלויות - מחלף גנות
# 168939       12018020841           2018  מחלף קיבוץ גלויות - מחלף גנות
# 182897       32019015243           2019  מחלף קיבוץ גלויות - מחלף גנות
# 208058       32015032901           2015  מחלף קיבוץ גלויות - מחלף גנות
# 220696       32020091910           2020  מחלף קיבוץ גלויות - מחלף גנות
# 270856       32019020991           2019  מחלף קיבוץ גלויות - מחלף גנות
# 272791       32017062375           2017  מחלף קיבוץ גלויות - מחלף גנות
# 325341       32017021729           2017  מחלף קיבוץ גלויות - מחלף גנות
# 372655       32019044319           2019  מחלף קיבוץ גלויות - מחלף גנות
# 385925       32019060425           2019  מחלף קיבוץ גלויות - מחלף גנות
# 428530       32019083976           2019  מחלף קיבוץ גלויות - מחלף גנות
# 483277       32017097720           2017  מחלף קיבוץ גלויות - מחלף גנות
# 1830913      32019024840           2019  מחלף קיבוץ גלויות - מחלף גנות
#
#          road_segment_id  road_segment_length_km   latitude  longitude  \
# 262132           10010.0                     4.6  31.995741  34.876132
# 79852            10010.0                     4.6  31.985041  34.892274
# 630376           10010.0                     4.6  31.985041  34.892274
# 1290954          10010.0                     4.6  31.980103  34.901051
# 193073           10010.0                     4.6  31.980103  34.901051
# 1096313          10010.0                     4.6  31.960313  34.935421
# 293439           10010.0                     4.6  31.925197  34.927096
# 298283           10010.0                     4.6  31.900807  34.937782
# 33514            10010.0                     4.6  31.818555  35.021194
# 171836           10010.0                     4.6  31.804907  35.045774
# 779062           10010.0                     4.6  31.799843  35.114516
# 1060965          10010.0                     4.6  31.799843  35.114516
# 579800           10010.0                     4.6  31.799843  35.114516
# 581871           10010.0                     4.6  31.799843  35.114516
# 592955           10010.0                     4.6  31.799843  35.114516
# 898267           10010.0                     4.6  31.799843  35.114516
# 873280           10010.0                     4.6  31.799843  35.114516
# 601060           10010.0                     4.6  31.799843  35.114516
# 605017           10010.0                     4.6  31.799843  35.114516
# 867216           10010.0                     4.6  31.799843  35.114516
# 618466           10010.0                     4.6  31.799843  35.114516
# 842329           10010.0                     4.6  31.799843  35.114516
# 822673           10010.0                     4.6  31.799843  35.114516
# 693843           10010.0                     4.6  31.799843  35.114516
# 550539           10010.0                     4.6  31.799843  35.114516
# 699630           10010.0                     4.6  31.799843  35.114516
# 723687           10010.0                     4.6  31.799843  35.114516
# 738248           10010.0                     4.6  31.799843  35.114516
# 796848           10010.0                     4.6  31.799843  35.114516
# 535859           10010.0                     4.6  31.799843  35.114516
# 424499           10010.0                     4.6  31.799843  35.114516
# 464243           10010.0                     4.6  31.799843  35.114516
# 39327            10010.0                     4.6  31.799843  35.114516
# 42999            10010.0                     4.6  31.799843  35.114516
# 58674            10010.0                     4.6  31.799843  35.114516
# 70386            10010.0                     4.6  31.799843  35.114516
# 78075            10010.0                     4.6  31.799843  35.114516
# 96828            10010.0                     4.6  31.799843  35.114516
# 96862            10010.0                     4.6  31.799843  35.114516
# 136624           10010.0                     4.6  31.799843  35.114516
# 138568           10010.0                     4.6  31.799843  35.114516
# 149832           10010.0                     4.6  31.799843  35.114516
# 153678           10010.0                     4.6  31.799843  35.114516
# 168939           10010.0                     4.6  31.799843  35.114516
# 182897           10010.0                     4.6  31.799843  35.114516
# 208058           10010.0                     4.6  31.799843  35.114516
# 220696           10010.0                     4.6  31.799843  35.114516
# 270856           10010.0                     4.6  31.799843  35.114516
# 272791           10010.0                     4.6  31.799843  35.114516
# 325341           10010.0                     4.6  31.799843  35.114516
# 372655           10010.0                     4.6  31.799843  35.114516
# 385925           10010.0                     4.6  31.799843  35.114516
# 428530           10010.0                     4.6  31.799843  35.114516
# 483277           10010.0                     4.6  31.799843  35.114516
# 1830913          10010.0                     4.6  31.799843  35.114516
#
#                 x         y injury_severity_hebrew  km_from_median
# 262132   188425.0  655886.0                פצוע קל            7.23
# 79852    189947.0  654695.0                פצוע קל            9.14
# 630376   189947.0  654695.0                פצוע קל            9.14
# 1290954  190775.0  654145.0                פצוע קל           10.14
# 193073   190775.0  654145.0                פצוע קל           10.14
# 1096313  194018.0  651942.0                פצוע קל           14.05
# 293439   193221.0  648050.0                פצוע קל           15.90
# 298283   194225.0  645343.0                פצוע קל           18.57
# 33514    202100.0  636206.0                    NaN           30.64
# 171836   204425.0  634689.0                    NaN           33.31
# 779062   210934.0  634120.0                    NaN           38.33
# 1060965  210934.0  634120.0                פצוע קל           38.33
# 579800   210934.0  634120.0                פצוע קל           38.33
# 581871   210934.0  634120.0                    NaN           38.33
# 592955   210934.0  634120.0                    NaN           38.33
# 898267   210934.0  634120.0                פצוע קל           38.33
# 873280   210934.0  634120.0                    NaN           38.33
# 601060   210934.0  634120.0                    NaN           38.33
# 605017   210934.0  634120.0                פצוע קל           38.33
# 867216   210934.0  634120.0                פצוע קל           38.33
# 618466   210934.0  634120.0               פצוע קשה           38.33
# 842329   210934.0  634120.0                פצוע קל           38.33
# 822673   210934.0  634120.0                פצוע קל           38.33
# 693843   210934.0  634120.0                    NaN           38.33
# 550539   210934.0  634120.0                פצוע קל           38.33
# 699630   210934.0  634120.0                פצוע קל           38.33
# 723687   210934.0  634120.0                פצוע קל           38.33
# 738248   210934.0  634120.0                פצוע קל           38.33
# 796848   210934.0  634120.0                פצוע קל           38.33
# 535859   210934.0  634120.0                פצוע קל           38.33
# 424499   210934.0  634120.0                    NaN           38.33
# 464243   210934.0  634120.0                פצוע קל           38.33
# 39327    210934.0  634120.0                    NaN           38.33
# 42999    210934.0  634120.0                פצוע קל           38.33
# 58674    210934.0  634120.0                    NaN           38.33
# 70386    210934.0  634120.0                פצוע קל           38.33
# 78075    210934.0  634120.0                    NaN           38.33
# 96828    210934.0  634120.0                פצוע קל           38.33
# 96862    210934.0  634120.0                פצוע קל           38.33
# 136624   210934.0  634120.0                פצוע קל           38.33
# 138568   210934.0  634120.0                פצוע קל           38.33
# 149832   210934.0  634120.0               פצוע קשה           38.33
# 153678   210934.0  634120.0                פצוע קל           38.33
# 168939   210934.0  634120.0                    NaN           38.33
# 182897   210934.0  634120.0                    NaN           38.33
# 208058   210934.0  634120.0                פצוע קל           38.33
# 220696   210934.0  634120.0                פצוע קל           38.33
# 270856   210934.0  634120.0                פצוע קל           38.33
# 272791   210934.0  634120.0                    NaN           38.33
# 325341   210934.0  634120.0                    NaN           38.33
# 372655   210934.0  634120.0                פצוע קל           38.33
# 385925   210934.0  634120.0                פצוע קל           38.33
# 428530   210934.0  634120.0                פצוע קל           38.33
# 483277   210934.0  634120.0                פצוע קל           38.33
# 1830913  210934.0  634120.0                    NaN           38.33

# %%
plot_outliers(filtered, outliers_test)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
segmend_id = 650020
segment_rows = filtered[filtered[ROAD_SEGMENT]==segmend_id]

outliers_test = calc_outliers_for_segment_km(segment_rows, MIN_SAMPLE_SIZE)

plot_outliers(filtered, outliers_test)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The algorithm can't detect outliers that are very close to the start or the end of the segment.
# Note that there is one coord at צומת חדרה מזרח
# Should it be in this segment or the next segment?

# %% [markdown]
# ### Test segment padding

# %%
segmend_id = 650030
segment_rows = filtered[filtered[ROAD_SEGMENT]==segmend_id]

# %%
outliers_test = calc_outliers_for_segment_km(segment_rows, MIN_SAMPLE_SIZE, padding=0)
len(outliers_test)
# Out:
# 27

# %%
outliers_test.head()
# Out:
#         provider_and_id  accident_year  \
# 4635        32020034458           2020
# 824257      32014091699           2014
# 785725      12016080255           2016
# 784117      12016027568           2016
# 760624      12015083066           2015
#
#                                 road_segment_name  road_segment_id  \
# 4635    צומת חדרה (מזרח) - צומת אלון (שמורת אלון)         650030.0
# 824257  צומת חדרה (מזרח) - צומת אלון (שמורת אלון)         650030.0
# 785725  צומת חדרה (מזרח) - צומת אלון (שמורת אלון)         650030.0
# 784117  צומת חדרה (מזרח) - צומת אלון (שמורת אלון)         650030.0
# 760624  צומת חדרה (מזרח) - צומת אלון (שמורת אלון)         650030.0
#
#         road_segment_length_km   latitude  longitude         x         y  \
# 4635                       1.2  32.447831  34.943457  194909.0  706002.0
# 824257                     1.2  32.447831  34.943457  194909.0  706002.0
# 785725                     1.2  32.447831  34.943457  194909.0  706002.0
# 784117                     1.2  32.447831  34.943457  194909.0  706002.0
# 760624                     1.2  32.447831  34.943457  194909.0  706002.0
#
#        injury_severity_hebrew  km_from_median
# 4635                      NaN             1.5
# 824257                    NaN             1.5
# 785725                פצוע קל             1.5
# 784117                    NaN             1.5
# 760624                פצוע קל             1.5

# %% [markdown]
# road_segment_length_km should be 1.9 according to google maps

# %%
plot_outliers(filtered, outliers_test)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
outliers_test = calc_outliers_for_segment_km(segment_rows, MIN_SAMPLE_SIZE, padding=0.2)
len(outliers_test)
# Out:
# 27

# %%
outliers_test = calc_outliers_for_segment_km(segment_rows, MIN_SAMPLE_SIZE, padding=0.25)
len(outliers_test)
# Out:
# 0

# %%
segmend_id = 440010
segment_rows = filtered[filtered[ROAD_SEGMENT]==segmend_id]
outliers_test = calc_outliers_for_segment_km(segment_rows, MIN_SAMPLE_SIZE, padding=0.25)

outliers_test
# Out:
#          provider_and_id  accident_year                 road_segment_name  \
# 267975       32018070927           2018  צומת שמשון - צומת נחשון (הגבורה)
# 287602       32019031467           2019  צומת שמשון - צומת נחשון (הגבורה)
# 661535       32019052527           2019  צומת שמשון - צומת נחשון (הגבורה)
# 931886       32019030852           2019  צומת שמשון - צומת נחשון (הגבורה)
# 1404219      32019092402           2019  צומת שמשון - צומת נחשון (הגבורה)
#
#          road_segment_id  road_segment_length_km   latitude  longitude  \
# 267975          440010.0                    10.3  31.895740  34.887068
# 287602          440010.0                    10.3  31.895740  34.887068
# 661535          440010.0                    10.3  31.895740  34.887068
# 931886          440010.0                    10.3  31.895740  34.887068
# 1404219         440010.0                    10.3  31.939954  34.865469
#
#                 x         y injury_severity_hebrew  km_from_median
# 267975   189426.0  644794.0                    NaN           13.06
# 287602   189426.0  644794.0                    NaN           13.06
# 661535   189426.0  644794.0                    NaN           13.06
# 931886   189426.0  644794.0                    NaN           13.06
# 1404219  187398.0  649703.0                פצוע קל           18.29

# %%
plot_outliers(filtered, outliers_test)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Calculate all outliers

# %%
outliers_by_km = get_outliers_by_km(filtered, MIN_SAMPLE_SIZE)
len(outliers_by_km)
# Out:
# 534

# %% [markdown]
# ### Segments with outliers

# %%
len(outliers_by_km[ROAD_SEGMENT].unique())
# Out:
# 56

# %%
outliers_by_km.head(10)
# Out:
#          provider_and_id  accident_year              road_segment_name  \
# 262132       32014096076           2014  מחלף קיבוץ גלויות - מחלף גנות
# 79852        32016097605           2016  מחלף קיבוץ גלויות - מחלף גנות
# 630376       32014086342           2014  מחלף קיבוץ גלויות - מחלף גנות
# 1290954      32015074726           2015  מחלף קיבוץ גלויות - מחלף גנות
# 193073       32015032765           2015  מחלף קיבוץ גלויות - מחלף גנות
# 1096313      32016024246           2016  מחלף קיבוץ גלויות - מחלף גנות
# 293439       32014038567           2014  מחלף קיבוץ גלויות - מחלף גנות
# 298283       32014002960           2014  מחלף קיבוץ גלויות - מחלף גנות
# 33514        32015070182           2015  מחלף קיבוץ גלויות - מחלף גנות
# 171836       32015057939           2015  מחלף קיבוץ גלויות - מחלף גנות
#
#          road_segment_id  road_segment_length_km   latitude  longitude  \
# 262132           10010.0                     4.6  31.995741  34.876132
# 79852            10010.0                     4.6  31.985041  34.892274
# 630376           10010.0                     4.6  31.985041  34.892274
# 1290954          10010.0                     4.6  31.980103  34.901051
# 193073           10010.0                     4.6  31.980103  34.901051
# 1096313          10010.0                     4.6  31.960313  34.935421
# 293439           10010.0                     4.6  31.925197  34.927096
# 298283           10010.0                     4.6  31.900807  34.937782
# 33514            10010.0                     4.6  31.818555  35.021194
# 171836           10010.0                     4.6  31.804907  35.045774
#
#                 x         y injury_severity_hebrew  km_from_median
# 262132   188425.0  655886.0                פצוע קל            7.23
# 79852    189947.0  654695.0                פצוע קל            9.14
# 630376   189947.0  654695.0                פצוע קל            9.14
# 1290954  190775.0  654145.0                פצוע קל           10.14
# 193073   190775.0  654145.0                פצוע קל           10.14
# 1096313  194018.0  651942.0                פצוע קל           14.05
# 293439   193221.0  648050.0                פצוע קל           15.90
# 298283   194225.0  645343.0                פצוע קל           18.57
# 33514    202100.0  636206.0                    NaN           30.64
# 171836   204425.0  634689.0                    NaN           33.31

# %% [markdown]
# ## Unreliable segments
# **Most of the coords are wrong, therefore it is not possible to find outliers - the median is in the wrong coord**

# %% [markdown]
# צומת מעבר רפיח - צומת חבל עזה 40006
#
# 70040 מחלף בני דרום - צומת בית רבן
#
# 70050 צומת בית רבן - מחלף גדרה
#
# 4120010 צומת ביל"ו - כניסה לרחובות דרך הפרדסים
#
# 6520003 צומת שפיה - כניסה לזכרון יעקב (ישן)
#
# 440030 צומת גזר - מחלף רמלוד
#
# 600005 יישוב באר שבע (לערד) - צומת חטיבת הנגב
#
# 4120010 צומת ביל"ו - כניסה לרחובות דרך הפרדסים
#
# 4120020 מפגש עם מסילת ברזל - צומת נס ציונה

# %% [markdown]
# **Wrong segment length**

# %% [markdown]
# Should be 4.5 km, segment_length=0.8
# 550030 צומת כפר סבא (מזרח) - צומת לאלפי מנשה

# %%
unreliable_segment_ids = [40006, 70040, 70050, 4120010, 6520003, 440030, 600005, 4120010, 4120020]

segment_rows = filtered[filtered[ROAD_SEGMENT].isin(unreliable_segment_ids)]
unreliable_segments_outliers = get_outliers_by_km(segment_rows, MIN_SAMPLE_SIZE)

# %%
unreliable_segments_outliers
# Out:
#          provider_and_id  accident_year  \
# 540613       32015062919           2015
# 830628       32015035754           2015
# 304738       12015020261           2015
# 4003         32014067024           2014
# 700652       32014093457           2014
# ...                  ...            ...
# 738371       32020008535           2020
# 739387       32015028670           2015
# 659000       12017017197           2017
# 1509886      12018034544           2018
# 636598       32016073954           2016
#
#                               road_segment_name  road_segment_id  \
# 540613            צומת מעבר רפיח - צומת חבל עזה          40006.0
# 830628            צומת מעבר רפיח - צומת חבל עזה          40006.0
# 304738            צומת מעבר רפיח - צומת חבל עזה          40006.0
# 4003              צומת מעבר רפיח - צומת חבל עזה          40006.0
# 700652            צומת מעבר רפיח - צומת חבל עזה          40006.0
# ...                                         ...              ...
# 738371   צומת ביל"ו - כניסה לרחובות דרך הפרדסים        4120010.0
# 739387   צומת ביל"ו - כניסה לרחובות דרך הפרדסים        4120010.0
# 659000       מפגש עם מסילת ברזל - צומת נס ציונה        4120020.0
# 1509886      מפגש עם מסילת ברזל - צומת נס ציונה        4120020.0
# 636598      צומת שפיה - כניסה לזכרון יעקב (ישן)        6520003.0
#
#          road_segment_length_km   latitude  longitude         x         y  \
# 540613                     46.8  32.300595  34.899988  190775.0  689685.0
# 830628                     46.8  32.202832  34.884511  189285.0  678848.0
# 304738                     46.8  32.186298  34.889977  189795.0  677013.0
# 4003                       46.8  32.177709  34.888469  189650.0  676061.0
# 700652                     46.8  32.177709  34.888469  189650.0  676061.0
# ...                         ...        ...        ...       ...       ...
# 738371                      1.6  31.965546  34.802908  181493.0  652561.0
# 739387                      1.6  31.992308  34.813363  182492.0  655525.0
# 659000                      1.5  31.908342  34.805335  181699.0  646217.0
# 1509886                     1.5  31.908342  34.805335  181699.0  646217.0
# 636598                      1.0  32.575515  34.965037  196970.0  720157.0
#
#         injury_severity_hebrew  km_from_median
# 540613                     NaN           62.35
# 830628                 פצוע קל           73.21
# 304738                 פצוע קל           74.85
# 4003                       NaN           75.81
# 700652                     NaN           75.81
# ...                        ...             ...
# 738371                     NaN            7.24
# 739387                 פצוע קל           10.19
# 659000                 פצוע קל            2.51
# 1509886                פצוע קל            2.51
# 636598                 פצוע קל            6.14
#
# [90 rows x 11 columns]

# %%
outliers_by_km_filtered = outliers_by_km[~outliers_by_km[ROAD_SEGMENT].isin(unreliable_segment_ids)]
outlier_map = plot_outliers(filtered, outliers_by_km_filtered)

outlier_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
outliers_by_km_unreliable = outliers_by_km[outliers_by_km[ROAD_SEGMENT].isin(unreliable_segment_ids)]
outlier_map_unreliable = plot_outliers(filtered, outliers_by_km_unreliable)

outlier_map_unreliable
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Severe outliers

# %%
severe_outliers = outliers_by_km.loc[(outliers_by_km[SEVERITY] == SEVERITY_HARD) | (outliers_by_km[SEVERITY] == SEVERITY_DEAD)]
print(len(severe_outliers))
severe_outliers
# Out:
# 11
#          provider_and_id  accident_year              road_segment_name  \
# 618466       12019063641           2019  מחלף קיבוץ גלויות - מחלף גנות
# 149832       12017054749           2017  מחלף קיבוץ גלויות - מחלף גנות
# 356736       12016068274           2016     מחלף אשדוד - מחלף בני דרום
# 1573338      12015055829           2015     מחלף חולות - מחלף משה דיין
# 1512650      12019031576           2019     מחלף חולות - מחלף משה דיין
# 508948       12017016314           2017        צומת להבים - מחלף להבים
# 57526        12016058694           2016        כניסה לעומר - צומת שוקת
# 128068       12019053708           2019       צומת עין אפק - מחלף גלעם
# 211176       12018031336           2018        צומת תל עכו - צומת יסיף
# 185573       12019032255           2019        צומת האלה - צומת עציונה
# 779930       12020027168           2020   צומת גבעת כ"ח - כניסה לרנתיס
#
#          road_segment_id  road_segment_length_km   latitude  longitude  \
# 618466           10010.0                     4.6  31.799843  35.114516
# 149832           10010.0                     4.6  31.799843  35.114516
# 356736           70030.0                     0.6  31.797965  34.798619
# 1573338         200005.0                     4.4  32.081591  34.797900
# 1512650         200005.0                     4.4  32.081591  34.797900
# 508948          310010.0                     3.2  31.255024  35.139688
# 57526           600012.0                     7.2  31.627132  35.132833
# 128068          790001.0                     5.0  32.780162  35.203770
# 211176          850002.0                     7.1  32.927923  35.319304
# 185573         3750010.0                     5.4  31.711315  35.054352
# 779930         4650010.0                     6.5  32.007056  35.103149
#
#                 x         y injury_severity_hebrew  km_from_median
# 618466   210934.0  634120.0               פצוע קשה           38.33
# 149832   210934.0  634120.0               פצוע קשה           38.33
# 356736   181018.0  633980.0               פצוע קשה            9.83
# 1573338  181068.0  665431.0               פצוע קשה           13.06
# 1512650  181068.0  665431.0                   הרוג           13.06
# 508948   213282.0  573709.0               פצוע קשה           35.33
# 57526    212656.0  614968.0                   הרוג           45.26
# 128068   219387.0  742827.0               פצוע קשה           11.88
# 211176   230193.0  759220.0               פצוע קשה           18.33
# 185573   205223.0  624310.0               פצוע קשה            9.45
# 779930   209879.0  657098.0               פצוע קשה           11.83

# %%
plot_outliers(filtered, severe_outliers)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Old method - Z scores

# %%
outliers_zscore = get_outliers_by_z_scores(filtered, ZSCORE_THRESH, MIN_SAMPLE_SIZE, check_by_km=False)
len(outliers_zscore)
# Out:
# 47

# %% [markdown]
# After removing false positives by checking distance from median:

# %%
outliers_zscore = get_outliers_by_z_scores(filtered, ZSCORE_THRESH, MIN_SAMPLE_SIZE)
len(outliers_zscore)
# Out:
# 44

# %%
severe_outliers_zscore = outliers_zscore.loc[(outliers_zscore[SEVERITY] == SEVERITY_HARD) | (outliers_zscore[SEVERITY] == SEVERITY_DEAD)]
severe_outliers_zscore
# Out:
#         provider_and_id  accident_year        road_segment_name  \
# 57526       12016058694           2016  כניסה לעומר - צומת שוקת
# 211176      12018031336           2018  צומת תל עכו - צומת יסיף
#
#         road_segment_id  road_segment_length_km   latitude  longitude  \
# 57526          600012.0                     7.2  31.627132  35.132833
# 211176         850002.0                     7.1  32.927923  35.319304
#
#                x         y injury_severity_hebrew
# 57526   212656.0  614968.0                   הרוג
# 211176  230193.0  759220.0               פצוע קשה

# %% [markdown]
# By using z-scores, only 44 outliers are detected (versus 534)

# %% [markdown]
# ## Save output

# %%
len(filtered), len(outliers_by_km)
# Out:
# (373239, 508)

# %%
outliers_by_km.to_csv("outliers.csv", header=True, index=False, encoding='utf-8')

# %%
unreliable_segment_ids = [40006, 70040, 70050, 4120010, 6520003, 440030, 600005, 4120010, 4120020]

unreliable_segments = filtered[filtered[ROAD_SEGMENT].isin(unreliable_segment_ids)]

unreliable_segments.to_csv("unreliable_segments.csv", header=True, index=False, encoding='utf-8')

# %%
outlier_map.save('outliers.html')
outlier_map_unreliable.save('unreliable_segments.html')
